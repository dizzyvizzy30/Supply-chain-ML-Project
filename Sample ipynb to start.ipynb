# %%
# Activate Virtual Environment (macOS/Linux)
# !source venv/bin/activate
# Install Required Packages
# !pip install ipykernel pandas boto3
# Register IPython Kernel
# !python -m ipykernel install --user --name=ml_supplychain_venv --display-name "Current Project name"
# Check Python Executable
import sys
print(sys.executable)
# Test Installed Packages
import pandas as pd
import boto3
print("pandas version:", pd.__version__)
print("boto3 version:", boto3.__version__)
# Out:
# zsh:source:1: no such file or directory: venv/bin/activate
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (6.31.0)
# Collecting pandas
#   Downloading pandas-2.3.3-cp39-cp39-macosx_10_9_x86_64.whl.metadata (91 kB)
# Collecting boto3
#   Downloading boto3-1.41.5-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: appnope>=0.1.2 in ./.venv/lib/python3.9/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.9/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.9/site-packages (from ipykernel) (8.18.1)
# Requirement already satisfied: jupyter-client>=8.0.0 in ./.venv/lib/python3.9/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.9/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in ./.venv/lib/python3.9/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in ./.venv/lib/python3.9/site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in ./.venv/lib/python3.9/site-packages (from ipykernel) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in ./.venv/lib/python3.9/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in ./.venv/lib/python3.9/site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.9/site-packages (from ipykernel) (5.14.3)
# Collecting numpy>=1.22.4 (from pandas)
#   Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting botocore<1.42.0,>=1.41.5 (from boto3)
#   Downloading botocore-1.41.5-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.16.0,>=0.15.0 (from boto3)
#   Downloading s3transfer-0.15.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting urllib3<1.27,>=1.25.4 (from botocore<1.42.0,>=1.41.5->boto3)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (4.15.0)
# Requirement already satisfied: exceptiongroup in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (1.3.1)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: importlib-metadata>=4.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-client>=8.0.0->ipykernel) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=8.0.0->ipykernel) (3.23.0)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.3)
# Downloading pandas-2.3.3-cp39-cp39-macosx_10_9_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 41.4 MB/s  0:00:00eta 0:00:01
# Downloading boto3-1.41.5-py3-none-any.whl (139 kB)
# Downloading botocore-1.41.5-py3-none-any.whl (14.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 48.7 MB/s  0:00:00m0:00:01
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.15.0-py3-none-any.whl (85 kB)
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
# Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 49.3 MB/s  0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, urllib3, tzdata, numpy, jmespath, pandas, botocore, s3transfer, boto3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [boto3]32m8/9 [boto3]sfer]
# Successfully installed boto3-1.41.5 botocore-1.41.5 jmespath-1.0.1 numpy-2.0.2 pandas-2.3.3 pytz-2025.2 s3transfer-0.15.0 tzdata-2025.2 urllib3-1.26.20
# Installed kernelspec ml_supplychain_venv in /Users/asparikh30/Library/Jupyter/kernels/ml_supplychain_venv
# /Users/asparikh30/Desktop/dizzyvizzy_git_projects/Supply-chain-ML-Project/.venv/bin/python
# pandas version: 2.3.3
# boto3 version: 1.41.5

# %%
# Activate Virtual Environment (macOS/Linux)
# !source venv/bin/activate
# Install Required Packages

# %%
# !pip install ipykernel pandas boto3
# Register IPython Kernel
# !python -m ipykernel install --user --name=ml_supplychain_venv --display-name "Current Project name"
# Out:
# Requirement already satisfied: ipykernel in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (6.30.1)
# Requirement already satisfied: pandas in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (2.3.2)
# Requirement already satisfied: boto3 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (1.40.26)
# Requirement already satisfied: appnope>=0.1.2 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipykernel) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipykernel) (9.5.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: botocore<1.41.0,>=1.40.26 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from boto3) (1.40.26)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from boto3) (0.13.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from botocore<1.41.0,>=1.40.26->boto3) (2.5.0)
# Requirement already satisfied: six>=1.5 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: decorator in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Installed kernelspec ml_supplychain_venv in /Users/asparikh30/Library/Jupyter/kernels/ml_supplychain_venv

# %%
# Check Python Executable
import sys
print(sys.executable)
# Out:
# /Users/asparikh30/Desktop/dizzyvizzy_git_projects/machine_learning_projects/ml_supplychain_pricing_project/venv/bin/python

# %%
# Test Installed Packages
import pandas as pd
import boto3
print("pandas version:", pd.__version__)
print("boto3 version:", boto3.__version__)
# Out:
# pandas version: 2.3.2
# boto3 version: 1.40.26

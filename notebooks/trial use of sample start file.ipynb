# %%
# Activate Virtual Environment (macOS/Linux)
# !source venv/bin/activate
# Install Required Packages
# !pip install ipykernel pandas boto3
# Register IPython Kernel
# !python -m ipykernel install --user --name=ml_supplychain_venv --display-name "Current Project name"
# Check Python Executable
import sys
print(sys.executable)
# Test Installed Packages
import pandas as pd
import boto3
print("pandas version:", pd.__version__)
print("boto3 version:", boto3.__version__)
# Out:
# zsh:source:1: no such file or directory: venv/bin/activate
# ...
# Installed kernelspec ml_supplychain_venv in /Users/asparikh30/Library/Jupyter/kernels/ml_supplychain_venv
# /Users/asparikh30/Desktop/dizzyvizzy_git_projects/Supply-chain-ML-Project/.venv/bin/python
# pandas version: 2.3.3
# boto3 version: 1.41.5

# %%
# Run the S3 data reader script
# %run ../src/read_s3_data.py
    
# After running, the 'df' variable will be available in this notebook
print(f"\nDataFrame shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
# Out:
# Reading SCMS_Delivery_History_Dataset.csv from s3://ml-supplychain-project ...
# Data read successfully!
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
# ...

# %%
len(df)
# Out:
# 10324
